# %% [markdown]
# <a href="https://colab.research.google.com/github/Jav007/edd_1310_2021/blob/main/JuegoDeLaVida_Tarea_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 from copy import deepcopy
class Array2D:
 
    def __init__(self,rows, cols, value):
        self.__cols = cols
        self.__rows = rows
        self.__array=[[value for x in range(self.__cols)] for y in range(self.__rows)]
 
    def to_string(self):
        [print("---",end="") for x in range(self.__cols)]
        print("")
        for ren in self.__array:
            print(ren)
        [print("---",end="") for x in range(self.__cols)]
        print("")
 
    def get_num_rows(self):       
        return self.__rows
 
    def get_num_cols(self):
        return self.__cols
 
    def get_item(self,row,col):
        return self.__array[row][col]
 
    def set_item( self , row , col , valor ):
        self.__array[row][col]=valor
 
    def clearing(self, valor=0):
        for ren in range(self.__rows):
            for col in range(self.__cols):
                self.__array[ren][col]=valor
 
class Juego:
    CELULA_VIVA = 1
    CELULA_MUERTA = 0
 
    def __init__(self,rens,cols,generaciones,poblacion):
        self.largo = cols
        self.alto = rens
        self.grid = Array2D( self.alto , self.largo,0 )
        self.gridN = Array2D( self.alto , self.largo,0 )
        self.grid.clearing(self.CELULA_MUERTA)
        self.gridN.clearing(self.CELULA_MUERTA)
        self.generaciones = generaciones
 
        for celula in poblacion:
            self.grid.set_item(celula[0],celula[1],self.CELULA_VIVA)
            self.gridN.set_item(celula[0],celula[1],self.CELULA_VIVA)
 
    def imprime_grid(self):
        print("Inicio")
        for x in range(self.grid.get_num_rows()):
            for y in range(self.grid.get_num_cols()):
                if self.grid.get_item(x,y) == 0:
                    print("░░",end="") #░░
                else:
                    print("▓▓",end="") #▓▓
            print("")
        
        print("----------------")
 
    def get_num_rows(self):
        return self.largo
 
    def get_num_cols(self):
        return self.alto
 
    def set_celula_muerta(self, row, col):
        return self.gridN.set_item(row, col, self.CELULA_MUERTA)
 
    def set_celula_viva( self , row , col):
        return self.gridN.set_item(row, col, self.CELULA_VIVA)
 
    def get_is_viva( self , row , col ):
        return self.grid.get_item(row,col) == self.CELULA_VIVA
 
    def get_is_muerta(self , row , col):
        return self.grid.get_item(row,col) == self.CELULA_MUERTA
 
    def get_numero_vecinos_vivos(self,row,col):            
        SURROUNDING = (((row - 1)%self.grid.get_num_rows(), (col - 1)%self.grid.get_num_cols()),                   
                       ((row - 1)%self.grid.get_num_rows(), (col    )%self.grid.get_num_cols()),
                       ((row - 1)%self.grid.get_num_rows(), (col + 1)%self.grid.get_num_cols()),
                       ((row    )%self.grid.get_num_rows(), (col - 1)%self.grid.get_num_cols()),
                       ((row    )%self.grid.get_num_rows(), (col + 1)%self.grid.get_num_cols()),
                       ((row + 1)%self.grid.get_num_rows(), (col - 1)%self.grid.get_num_cols()),
                       ((row + 1)%self.grid.get_num_rows(), (col    )%self.grid.get_num_cols()),
                       ((row + 1)%self.grid.get_num_rows(), (col + 1)%self.grid.get_num_cols()))
        count = 0
        for row, cell in SURROUNDING:
            if self.grid.get_item(row,cell)==1:
                count += 1
        return count
 
    def evolucionar (self):
        
        for i in range(self.generaciones):
            self.gridN = deepcopy(self.grid)
            print(f"Generación {i+1}")
            for x in range(self.grid.get_num_rows()):
                for y in range(self.grid.get_num_cols()):
                
                    #if self.grid.get_item(x,y) == self.CELULA_MUERTA :
                    if self.get_is_muerta(x,y):
                        if self.get_numero_vecinos_vivos(x,y)==3:
                            print("▓▓",end="")
                            self.set_celula_viva(x,y)
                            #self.gridN.set_item(x,y,True)
                        elif self.get_numero_vecinos_vivos(x,y)!=3:
                            print("░░",end="")
                            self.set_celula_muerta(x,y)
                            #self.gridN.set_item(x,y,False)
 
                    #if self.grid.get_item(x,y) == self.CELULA_VIVA :
                    if self.get_is_viva(x,y):
                        if self.get_numero_vecinos_vivos(x,y)<2 or self.get_numero_vecinos_vivos(x,y)>3:
                            print("░░",end="")
                            self.set_celula_muerta(x,y)
                            #self.gridN.set_item(x,y,False)
                        elif self.get_numero_vecinos_vivos(x,y)==2 or self.get_numero_vecinos_vivos(x,y)==3:
                            print("▓▓",end="")
                            self.set_celula_viva(x,y)
                            #self.gridN.set_item(x,y,True)     
                print() 
            self.grid=self.gridN
                       
simulation = Juego(7,7,6,[(1,2),(2,1),(2,2),(2,3)])
simulation.imprime_grid()
simulation.evolucionar()
# Out:
# Inicio
# ░░░░░░░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ----------------
# Generación 1
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# Generación 2
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# Generación 3
# ░░░░▓▓░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# Generación 4
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# Generación 5
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ▓▓░░░░░░▓▓░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# Generación 6
# ░░░░▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ▓▓▓▓░░▓▓▓▓░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
